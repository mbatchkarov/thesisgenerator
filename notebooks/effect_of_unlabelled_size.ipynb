# %% [markdown]
# # How does the performance of a distributional model change as we train in on more and more labelled data?
#
#  - Pennington el al (2014) report `word2vec`'s performance at the word analogy task and a range of word similarity task improves with more data.
#  - My own experiments (in `euroscipy_demo` notebook) show performance at the analogy task roughly scales like this:
#
# <img src='files/img/word2vec_acc.png' align'middle'>

# %% [markdown]
# Let's investigate if the same holds for the document classification task. For simiplicity, we only look at `word2vec` vectors with simple composion on the Reuters data set.

# %% [raw]
# <!-- Don't display the code, just its results-->
# <style type="text/css">
#     .input_prompt, .input_area, .output_prompt { display:none !important; }
#     backgroundTransition: 'fade'
# </style>

# %%
# %cd ~/NetBeansProjects/thesisgenerator/
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg' 
import os
import peewee as pw
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from thesisgenerator.utils.db import ClassificationExperiment, Vectors, Results
from thesisgenerator.utils.output_utils import *

import logging, imp
imp.reload(logging)
logging.basicConfig(level=logging.INFO, format="%(levelname)s:\t%(message)s")
logging.info('test')
# Out:
# INFO:	test
# /Volumes/LocalDataHD/mmb28/NetBeansProjects/thesisgenerator

# %%
from operator import attrgetter
def query_to_ids(q):
    # eliminate duplicated experiments     
    experiments = set(ClassificationExperiment.get(ClassificationExperiment.id==res[0]) for res in q)
    return sorted(list(set(foo.id for foo in experiments)))

def get_exp_ids_for_varying_amounts_of_unlabelled(corpus='reuters21578/r8-tagged-grouped'):
    query = (ClassificationExperiment
             .select(ClassificationExperiment.id)
             .join(Vectors)
             .where(ClassificationExperiment.decode_handler == 'SignifiedOnlyFeatureHandler',
                    ClassificationExperiment.document_features == 'AN_NN',
                    ClassificationExperiment.labelled == corpus,
                    ClassificationExperiment.use_similarity == 0,
                    ClassificationExperiment.neighbour_strategy == 'linear',
                    ClassificationExperiment.k == 3,
                    Vectors.algorithm == 'word2vec',
                    Vectors.rep == 0).tuples())
    return(query_to_ids(query))

def get_exp_ids_for_reruns_of_word2vec(corpus='reuters21578/r8-tagged-grouped'):
    query = (ClassificationExperiment
             .select(ClassificationExperiment.id)
             .join(Vectors)
             .where(ClassificationExperiment.decode_handler == 'SignifiedOnlyFeatureHandler',
                    ClassificationExperiment.document_features == 'AN_NN',
                    ClassificationExperiment.labelled == corpus,
                    ClassificationExperiment.neighbour_strategy == 'linear',
                    ClassificationExperiment.use_similarity == 0,
                    Vectors.algorithm == 'word2vec',
                    ClassificationExperiment.k == 3,
                    Vectors.unlabelled_percentage == 100).tuples())
    return(query_to_ids(query))

# %% [markdown]
# # How much variation does the classification task introduce?

# %%
from itertools import chain

corpus = 'reuters21578/r8-tagged-grouped'
corpus = 'amazon_grouped-tagged'

ids = get_exp_ids_for_varying_amounts_of_unlabelled(corpus=corpus)
# print(len(ids))
scores, folds, ids = get_scores(ids)
# print(ids)
# print(len(get_vectors_field(ids, 'composer')))
# print(len(data), len(folds))
names = ['%s-%s'%(a,b) for a,b in zip(get_vectors_field(ids, 'algorithm'),
                                      get_vectors_field(ids, 'composer'))]
exp_ids = list(chain.from_iterable([foo] * 25 for foo in ids))
df1 = pd.DataFrame({'F1':scores, 
                   'Composer':names,
                   'cvfold':folds,
                   '% of corpus':get_vectors_field(ids, 'unlabelled_percentage'),
                   'ids':exp_ids})
# df1#['% of Gigaword']
df1.to_html('df.html')
# print(ids)
# for id in ids:
#     print(ClassificationExperiment.get(ClassificationExperiment.id==id).vectors.id)
# for foo in ClassificationExperiment.get(ClassificationExperiment.vectors.id==37):
#     print(foo)
# print(ids)
df1[df1.cvfold==0].sort('% of corpus').to_html('dfsmall.html')
ax = sns.tsplot(df1, time='% of corpus', condition='Composer', value='F1', unit='cvfold',
                err_style=['ci_band', 'ci_bars']);
_ = ax.set_title('Performance vs Amount of unlabelled data');
# _ = ax.set(ylim=(.5, .8)) 
# _ = ax.set(xlim=(None,10)) # zoom in on the left hand size


# random baseline
for alg in ['random_vect', 'random_neigh']:
    try: # I don't have random vect results for amazon
        rand_id = ClassificationExperiment.select().join(Vectors).where(Vectors.algorithm==alg, \
                                                                  ClassificationExperiment.labelled==corpus)[0].id
        score = Results.get(Results.id==rand_id).macrof1_mean
        score_std = Results.get(Results.id==rand_id).macrof1_std
        logging.info('Algorithm %s, id %d, score %0.2f +- %0.2f', alg, rand_id, score, score_std)
        ax.plot(range(0,101), [score]*101, label='alg');
    except Exception:
        continue
# Out:
# INFO:	Algorithm random_neigh, id 1, score 0.11 +- 0.00

# %% [markdown]
#  - there isn't a clear trend
#  - some variation introduced by classification task
#    - each run has a different vocabulary
#    - different set of candidate neighbours that can be inserted at decode time

# %% [markdown]
# # Variation due to `word2vec`'s random initialisation
#
#  - fairly small at the word analogy task

# %%
ids = get_exp_ids_for_reruns_of_word2vec()
data, folds, success = get_scores(ids)

# %%
df2 = pd.DataFrame({'F1': data,
                   'Composer': get_vectors_field(ids, 'composer'),
                   'cvfold': folds,
                   'Repetition': get_vectors_field(ids, 'rep')})
grid = sns.factorplot(x='Repetition', y='F1', data=df2, col='Composer',
                      kind='bar', sharey=True, size=4, col_wrap=2);
grid.set(ylim=(.6, .8));

# %% [markdown]
#  - word embeddings are reasonably stable
#  - the lines above for Left and Right are (mostly) flat
#      - TODO look deeper into this
#  - Composition, esp. multiplication, can result in very different phrase vectors

# %% [markdown]
# # Why is multiply so unstable?
# Things to look at
# - <s>compare vectors between multiple runs (before and after composition)</s>. The space is completely different, this makes no sense.
#  - compare neighbours of a sample of entries between runs
#   - without any constraints, out of the full vocabulary
#   - out of the neighbours present in the labelled data set
#       - redoing experiments [218, 313, 314] and [225, 315, 316] with stats enabled. These are word2vec repeated runs at 100% of gigaw with Add/Mult composer respectively
#
# - Could the whole variation be simply down to the small size of Reuters? Would using Amazon help?
#   - in general error bounds due to classification task are much smaller on Amazon (~1%) as apposed to ~3-4% on Reuters
#
# - Performance of `w2v` models I've trained on google's analogy task
#     - can't easily calculate as I have stemmed and added a pos tar => syntactic part of test is impossible to do
#     - compute something like Precision@K/MAP instead of accuracy of top neighbour

# %%
# Compare unigram vectors between multiple runs
from glob import glob
from discoutils.thesaurus_loader import Vectors as V
pattern = '/mnt/lustre/scratch/inf/mmb28/FeatureExtrationToolkit/word2vec_vectors/word2vec-100perc.unigr.strings.rep*'
# pattern = '/mnt/lustre/scratch/inf/mmb28/FeatureExtrationToolkit/word2vec_vectors/word2vec-wiki-100perc.unigr.strings.rep*'
files = sorted(glob(pattern))
thes = [V.from_tsv(f, gzipped=True) for f in files]
# Out:
# INFO:	Loading thesaurus /mnt/lustre/scratch/inf/mmb28/FeatureExtrationToolkit/word2vec_vectors/word2vec-100perc.unigr.strings.rep0 from disk
# INFO:	Loading thesaurus /mnt/lustre/scratch/inf/mmb28/FeatureExtrationToolkit/word2vec_vectors/word2vec-100perc.unigr.strings.rep1 from disk
# INFO:	Loading thesaurus /mnt/lustre/scratch/inf/mmb28/FeatureExtrationToolkit/word2vec_vectors/word2vec-100perc.unigr.strings.rep2 from disk

# %%
# all 3 runs should contain the same entries
assert all(x.keys() == thes[0].keys() for x in thes)
assert all(len(x) == len(thes[0]) for x in thes)

from scipy.spatial.distance import cosine, euclidean
from itertools import combinations
from random import sample

pairs = []
sims = []
s = sample([x for x in thes[0].keys() if x[-1] in 'NJ'], 500)
for i,j in combinations(range(len(thes)), 2):
    print('Doing pair %d and %d'%(i,j))
    d = [euclidean(thes[i].get_vector(foo).A, 
                   thes[j].get_vector(foo).A) for foo in s] # cosine distance
    sims.extend(d)
    pairs.extend(['%d-%d'%(i,j)]*(len(sims) - len(pairs)))
# Out:
# Doing pair 0 and 1
# Doing pair 0 and 2
# Doing pair 1 and 2

# %% [markdown]
# # Overlap of neighbours for $word_i$ across `word2vec` runs
# Dice coefficient over a small sample, neighbours selected out of the entire `word2vec` vocabulary

# %%
def dice(n1, n2):
    return 2 * len(set(n1) & set(n2))/ (len(n1) + len(n2))

for t in thes:
    t.init_sims()
pairs = []
sims = []
s = sample([x for x in thes[0].keys() if x[-1] in 'NJ'], 500)
for i,j in combinations(range(len(thes)), 2):
    print('Doing pair %d and %d'%(i,j))
    for num, foo in enumerate(s):
        n1 = [x[0] for x in thes[i].get_nearest_neighbours(foo)[:10]]
        n2 = [x[0] for x in thes[j].get_nearest_neighbours(foo)[:10]]
        sims.append(dice(n1, n2))
    pairs.extend(['%d-%d'%(i,j)]*(len(sims) - len(pairs)))
# Out:
# Doing pair 0 and 1
# Doing pair 0 and 2
# Doing pair 1 and 2

# %%
df3 = pd.DataFrame({'Pair': pairs,
                   'Dice': sims,
                   'Words' : s * 3})
g = sns.FacetGrid(df3, col="Pair");
g.map(sns.distplot, 'Dice');

# %% [markdown]
#  - Neighbour do not overlap much (not to mention their order)
#  - Should I report averaged performance across all runs of `word2vec`?
#
# If the neighbours vary so much, why is the performance of some composers so stable?
#   - Do some composers "magnify" differences in input vectors?
#   - Is it a matter of vocabulary coverage? the neighbours that we find here are different to the one the classifier finds

# %% [markdown]
# # Neighbours selected from ones in vocabulary (fold 0)

# %%
from thesisgenerator.scripts.analysis.signified_internals_analysis import get_replacements_df
from itertools import product

def get_neigh_from_df(df, feature):
    recorded_replacements = []
    for i in range(1, 4):
        r = df.loc[feature]['replacement%d' % i]
        if r:  # remove NaN
            recorded_replacements.append(r)
    return recorded_replacements

try:
    repl1 = get_replacements_df('statistics/stats-exp218-0-cv0-ev.par.csv') # todo hardcoded values, see above
    repl2 = get_replacements_df('statistics/stats-exp225-0-cv0-ev.par.csv')
except FileNotFoundError as e:
    raise ValueError('Cant find file')
assert set(repl1.index) == set(repl2.index)
s = sample(list(repl2.index), 100)
overlap = [dice(get_neigh_from_df(repl1, foo),
                get_neigh_from_df(repl2, foo)) for foo in s]
# print(len(composers), len(reps), len(overlap))
plt.hist(overlap, bins=4);
plt.xticks(np.arange(3)/3);
# Out:
# /Volumes/LocalDataHD/mmb28/anaconda/envs/py33/lib/python3.3/site-packages/matplotlib/__init__.py:1156: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# /Volumes/LocalDataHD/mmb28/anaconda/envs/py33/lib/python3.3/site-packages/pandas/io/parsers.py:635: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators; you can avoid this warning by specifying engine='python'.
#   ParserWarning)

# %% [markdown]
# ### It's even worse when we have a limited set of neighbours- the replacements of a given feature only match in ~5% of cases (partial match in ~25% of cases)

# %%
from collections import Counter
Counter(overlap)
# Out:
# Counter({0.0: 69, 0.3333333333333333: 27, 0.6666666666666666: 4})

# %%
X = thes[0].matrix[:100, :]
Y = thes[1].matrix[:100, :]

# %%
from sklearn.cross_decomposition import CCA
c = CCA()
x1, y1 = c.fit_transform(X.A, Y.A)

# %%
c.x_scores_.shape
# Out:
# (100, 2)

# %%
from sklearn.cross_decomposition import PLSRegression
p = PLSRegression()
p.fit(X[:200, :].A, Y[:200, :].A)
p.coef
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-46-960c6396c6ec> in <module>()
#       1 from sklearn.cross_decomposition import PLSRegression
#       2 p = PLSRegression()
# ----> 3 p.fit(X[:200, :].A, Y[:200, :].A)
#       4 p.coef
#
# /Volumes/LocalDataHD/mmb28/anaconda/envs/py33/lib/python3.3/site-packages/scipy/sparse/csr.py in __getitem__(self, key)
#     263                      row.step in (1, None))):
#     264                 # col is int or slice with step 1, row is slice with step 1.
# --> 265                 return self._get_submatrix(row, col)
#     266             elif issequence(col):
#     267                 P = extractor(col,self.shape[1]).T        # [1:2,[1,2]]
#
# /Volumes/LocalDataHD/mmb28/anaconda/envs/py33/lib/python3.3/site-packages/scipy/sparse/csr.py in _get_submatrix(self, row_slice, col_slice)
#     391         i0, i1 = process_slice(row_slice, M)
#     392         j0, j1 = process_slice(col_slice, N)
# --> 393         check_bounds(i0, i1, M)
#     394         check_bounds(j0, j1, N)
#     395
#
# /Volumes/LocalDataHD/mmb28/anaconda/envs/py33/lib/python3.3/site-packages/scipy/sparse/csr.py in check_bounds(i0, i1, num)
#     387                       "index out of bounds: 0 <= %d <= %d, 0 <= %d <= %d,"
#     388                        " %d <= %d" %
# --> 389                       (i0, num, i1, num, i0, i1))
#     390
#     391         i0, i1 = process_slice(row_slice, M)
#
# IndexError: index out of bounds: 0 <= 0 <= 100, 0 <= 200 <= 100, 0 <= 200

# %%
n = 1000
p = 10
X1 = np.random.normal(size=n * p).reshape((n, p))
y = X1[:, 0] + 2 * X1[:, 1] + np.random.normal(size=n * 1) + 5

# %%
X1.shape
# Out:
# (1000, 10)

# %%
y.shape
# Out:
# (1000,)

# %%
a = ClassificationExperiment.select().join(Vectors).where(Vectors.algorithm=='random', \
                                                          ClassificationExperiment.labelled=='reuters21578/r8-tagged-grouped')
print(a[0].id)
for foo in a:
    print(foo.id)
# Out:
# 41
# 41
