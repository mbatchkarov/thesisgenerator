# %%
# %matplotlib inline
# %cd /Volumes/LocalDataHD/mmb28/NetBeansProjects/thesisgenerator

from thesisgenerator.utils.conf_file_utils import parse_config_file
from thesisgenerator.utils.data_utils import get_tokenized_data, get_tokenizer_settings_from_conf_file
from thesisgenerator.plugins.bov import ThesaurusVectorizer
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.set_palette("deep", desat=.6)
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('svg')
path = '/Volumes/LocalDataHD/mmb28/Desktop/down/amazon_grouped-tagged.gz'
# Out:
# /Volumes/LocalDataHD/mmb28/NetBeansProjects/thesisgenerator

# %%
tok = get_tokenizer_settings_from_conf_file('conf/exp2/exp2_base.conf')
data = get_tokenized_data(path, tok)

# %%
Xtext, Y, _, _ = data
print(len(Xtext))
vect = ThesaurusVectorizer(ngram_range=(0, 0), min_df=1, use_tfidf=False,
                           extract_VO_features=False, extract_SVO_features=False,
                           unigram_feature_pos_tags=['N', 'J'])
X, _ = vect.fit_transform(Xtext)
# Out:
# 79800

# %%
sums = X.sum(axis=1)
sums[sums>200] = 200 # remove outliers
data = pd.Series(np.ravel(sums))
sns.boxplot(data, Y);
